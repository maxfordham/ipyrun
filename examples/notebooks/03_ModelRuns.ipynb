# %%
from mf_modules.excel_in import ExcelIn
from mf_modules.pydtype_operations import find_in_list
import pandas as pd

class Mruns():

    def __init__(self,
                 df_mruns,
                 grpchar='→',
                 keywordcols=[{'description': 'description'}, {'reference': 'ref'}],
                 indexcols=['report_model_run', 'as_designed', 'london_plan_run']  # , 'report_run_name'
                 ):
        self.df_mruns = df_mruns
        self.keywordcols = keywordcols
        self.indexcols = indexcols
        self.cols = list(df_mruns)
        self.grpchar = grpchar
        self.df_colsfilt = self.cols_filt()
        self.df_indexfilt = self.index_filt()

    def _group_cols(self):
        cols = ['core {0}'.format(self.grpchar)] + self.cols
        groups = ['core {0}'.format(self.grpchar)] + find_in_list(list(self.df_mruns), '→')
        di = {}
        for col in cols:
            if col in groups:
                grp = col
                continue
            di[col] = grp
        return di

    def cols_filt(self):
        grps = self._groupcols_filt()
        kywrds = self._keywordcols_filt()
        df = grps.join(kywrds)
        df = df.fillna(0)
        df = df.astype(int)
        return df

    def _groupcols_filt(self):
        grps = self._group_cols()
        df = pd.DataFrame.from_dict(grps, orient='index').rename(columns={0: 'group'})
        df['group'] = df['group'].str.replace(' {0}'.format(self.grpchar), '')
        grps = df.group.unique()
        for grp in grps:
            di = {grp: 1}
            df[grp] = 0
            df[grp] = df['group'].map(di)
        del df['group']
        return df

    def _keywordcols_filt(self):
        df = pd.DataFrame.from_dict({'cols': self.cols})
        df = df.set_index('cols')
        for k in self.keywordcols:
            for k, v in k.items():
                df[k] = 0
                li = find_in_list(self.cols, v)
                df.loc[li, k] = 1
        return df

    def index_filt(self):
        return self.df_mruns[self.indexcols].fillna(0).astype(int)

# %%
FPTH = r'..\..\data\model_runs\model_runs-partL.xlsm'
xl = ExcelIn(FPTH)
mruns = xl.pytable
m = Mruns(mruns.set_index('file_prefix'))

# %%
# an array that describes the grouping of hte model_runs spreadsheet
m.df_colsfilt
# Out:
#                                         core  user defined row filters  \
# model_run                                  1                         0
# description                                1                         0
# IesVersion                                 1                         0
# BER_kgCO2/(m2.yr)                          1                         0
# TER_kgCO2/(m2.yr)                          1                         0
# london_plan_run                            1                         0
# report_run_name                            1                         0
# as_designed                                0                         1
# report_model_run                           0                         1
# counter                                    0                         0
# tag                                        0                         0
# tag1                                       0                         0
# general ref                                0                         0
# drwg ref                                   0                         0
# weather data ref                           0                         0
# carbon factor ref                          0                         0
# electricity emission factor kgCO2/kWh      0                         0
# natural gas emission factor kgCO2/kWh      0                         0
# fabric uvals/gvals                         0                         0
# fabric description                         0                         0
# Air Permeability (m3/h.m2 @50Pa)           0                         0
# vent description                           0                         0
# MVHR heat recovery sensible efficiency     0                         0
# heating description                        0                         0
# heating control description                0                         0
# heating SCoP                               0                         0
# heating SCoP ref                           0                         0
# vent heat recovery effectiveness           0                         0
# dhw description                            0                         0
# dhw SCoP                                   0                         0
# dhw SCoP ref                               0                         0
# cooling description                        0                         0
# SSEER                                      0                         0
# SEER                                       0                         0
# EER                                        0                         0
# Delivery Efficiency                        0                         0
# cooling ref                                0                         0
# cooling ref2                               0                         0
# pv description                             0                         0
# module nominal efficiency                  0                         0
# Inclination (deg from horizontal)          0                         0
# Azimuth (deg from North)                   0                         0
# Shading Factor                             0                         0
# PV Area (m2)                               0                         0
# solar thermal description                  0                         0
# solar thermal area (m2)                    0                         0
# lighting description                       0                         0
# lighting efficacy (lm/w)                   0                         0
# lighting efficiency (W/m2.100lux)          0                         0
# lighting controls description              0                         0
# pump type description                      0                         0
#
#                                         naming model runs  \
# model_run                                               0
# description                                             0
# IesVersion                                              0
# BER_kgCO2/(m2.yr)                                       0
# TER_kgCO2/(m2.yr)                                       0
# london_plan_run                                         0
# report_run_name                                         0
# as_designed                                             0
# report_model_run                                        0
# counter                                                 1
# tag                                                     1
# tag1                                                    1
# general ref                                             0
# drwg ref                                                0
# weather data ref                                        0
# carbon factor ref                                       0
# electricity emission factor kgCO2/kWh                   0
# natural gas emission factor kgCO2/kWh                   0
# fabric uvals/gvals                                      0
# fabric description                                      0
# Air Permeability (m3/h.m2 @50Pa)                        0
# vent description                                        0
# MVHR heat recovery sensible efficiency                  0
# heating description                                     0
# heating control description                             0
# heating SCoP                                            0
# heating SCoP ref                                        0
# vent heat recovery effectiveness                        0
# dhw description                                         0
# dhw SCoP                                                0
# dhw SCoP ref                                            0
# cooling description                                     0
# SSEER                                                   0
# SEER                                                    0
# EER                                                     0
# Delivery Efficiency                                     0
# cooling ref                                             0
# cooling ref2                                            0
# pv description                                          0
# module nominal efficiency                               0
# Inclination (deg from horizontal)                       0
# Azimuth (deg from North)                                0
# Shading Factor                                          0
# PV Area (m2)                                            0
# solar thermal description                               0
# solar thermal area (m2)                                 0
# lighting description                                    0
# lighting efficacy (lm/w)                                0
# lighting efficiency (W/m2.100lux)                       0
# lighting controls description                           0
# pump type description                                   0
#
#                                         refs and linked files  carbon factors  \
# model_run                                                   0               0
# description                                                 0               0
# IesVersion                                                  0               0
# BER_kgCO2/(m2.yr)                                           0               0
# TER_kgCO2/(m2.yr)                                           0               0
# london_plan_run                                             0               0
# report_run_name                                             0               0
# as_designed                                                 0               0
# report_model_run                                            0               0
# counter                                                     0               0
# tag                                                         0               0
# tag1                                                        0               0
# general ref                                                 1               0
# drwg ref                                                    1               0
# weather data ref                                            1               0
# carbon factor ref                                           0               1
# electricity emission factor kgCO2/kWh                       0               1
# natural gas emission factor kgCO2/kWh                       0               1
# fabric uvals/gvals                                          0               0
# fabric description                                          0               0
# Air Permeability (m3/h.m2 @50Pa)                            0               0
# vent description                                            0               0
# MVHR heat recovery sensible efficiency                      0               0
# heating description                                         0               0
# heating control description                                 0               0
# heating SCoP                                                0               0
# heating SCoP ref                                            0               0
# vent heat recovery effectiveness                            0               0
# dhw description                                             0               0
# dhw SCoP                                                    0               0
# dhw SCoP ref                                                0               0
# cooling description                                         0               0
# SSEER                                                       0               0
# SEER                                                        0               0
# EER                                                         0               0
# Delivery Efficiency                                         0               0
# cooling ref                                                 0               0
# cooling ref2                                                0               0
# pv description                                              0               0
# module nominal efficiency                                   0               0
# Inclination (deg from horizontal)                           0               0
# Azimuth (deg from North)                                    0               0
# Shading Factor                                              0               0
# PV Area (m2)                                                0               0
# solar thermal description                                   0               0
# solar thermal area (m2)                                     0               0
# lighting description                                        0               0
# lighting efficacy (lm/w)                                    0               0
# lighting efficiency (W/m2.100lux)                           0               0
# lighting controls description                               0               0
# pump type description                                       0               0
#
#                                         fabric  vent  heat  dhw  cooling  PV  \
# model_run                                    0     0     0    0        0   0
# description                                  0     0     0    0        0   0
# IesVersion                                   0     0     0    0        0   0
# BER_kgCO2/(m2.yr)                            0     0     0    0        0   0
# TER_kgCO2/(m2.yr)                            0     0     0    0        0   0
# london_plan_run                              0     0     0    0        0   0
# report_run_name                              0     0     0    0        0   0
# as_designed                                  0     0     0    0        0   0
# report_model_run                             0     0     0    0        0   0
# counter                                      0     0     0    0        0   0
# tag                                          0     0     0    0        0   0
# tag1                                         0     0     0    0        0   0
# general ref                                  0     0     0    0        0   0
# drwg ref                                     0     0     0    0        0   0
# weather data ref                             0     0     0    0        0   0
# carbon factor ref                            0     0     0    0        0   0
# electricity emission factor kgCO2/kWh        0     0     0    0        0   0
# natural gas emission factor kgCO2/kWh        0     0     0    0        0   0
# fabric uvals/gvals                           1     0     0    0        0   0
# fabric description                           1     0     0    0        0   0
# Air Permeability (m3/h.m2 @50Pa)             1     0     0    0        0   0
# vent description                             0     1     0    0        0   0
# MVHR heat recovery sensible efficiency       0     1     0    0        0   0
# heating description                          0     0     1    0        0   0
# heating control description                  0     0     1    0        0   0
# heating SCoP                                 0     0     1    0        0   0
# heating SCoP ref                             0     0     1    0        0   0
# vent heat recovery effectiveness             0     0     1    0        0   0
# dhw description                              0     0     0    1        0   0
# dhw SCoP                                     0     0     0    1        0   0
# dhw SCoP ref                                 0     0     0    1        0   0
# cooling description                          0     0     0    0        1   0
# SSEER                                        0     0     0    0        1   0
# SEER                                         0     0     0    0        1   0
# EER                                          0     0     0    0        1   0
# Delivery Efficiency                          0     0     0    0        1   0
# cooling ref                                  0     0     0    0        1   0
# cooling ref2                                 0     0     0    0        1   0
# pv description                               0     0     0    0        0   1
# module nominal efficiency                    0     0     0    0        0   1
# Inclination (deg from horizontal)            0     0     0    0        0   1
# Azimuth (deg from North)                     0     0     0    0        0   1
# Shading Factor                               0     0     0    0        0   1
# PV Area (m2)                                 0     0     0    0        0   1
# solar thermal description                    0     0     0    0        0   0
# solar thermal area (m2)                      0     0     0    0        0   0
# lighting description                         0     0     0    0        0   0
# lighting efficacy (lm/w)                     0     0     0    0        0   0
# lighting efficiency (W/m2.100lux)            0     0     0    0        0   0
# lighting controls description                0     0     0    0        0   0
# pump type description                        0     0     0    0        0   0
#
#                                         solar thermal  lighting  auxilliary  \
# model_run                                           0         0           0
# description                                         0         0           0
# IesVersion                                          0         0           0
# BER_kgCO2/(m2.yr)                                   0         0           0
# TER_kgCO2/(m2.yr)                                   0         0           0
# london_plan_run                                     0         0           0
# report_run_name                                     0         0           0
# as_designed                                         0         0           0
# report_model_run                                    0         0           0
# counter                                             0         0           0
# tag                                                 0         0           0
# tag1                                                0         0           0
# general ref                                         0         0           0
# drwg ref                                            0         0           0
# weather data ref                                    0         0           0
# carbon factor ref                                   0         0           0
# electricity emission factor kgCO2/kWh               0         0           0
# natural gas emission factor kgCO2/kWh               0         0           0
# fabric uvals/gvals                                  0         0           0
# fabric description                                  0         0           0
# Air Permeability (m3/h.m2 @50Pa)                    0         0           0
# vent description                                    0         0           0
# MVHR heat recovery sensible efficiency              0         0           0
# heating description                                 0         0           0
# heating control description                         0         0           0
# heating SCoP                                        0         0           0
# heating SCoP ref                                    0         0           0
# vent heat recovery effectiveness                    0         0           0
# dhw description                                     0         0           0
# dhw SCoP                                            0         0           0
# dhw SCoP ref                                        0         0           0
# cooling description                                 0         0           0
# SSEER                                               0         0           0
# SEER                                                0         0           0
# EER                                                 0         0           0
# Delivery Efficiency                                 0         0           0
# cooling ref                                         0         0           0
# cooling ref2                                        0         0           0
# pv description                                      0         0           0
# module nominal efficiency                           0         0           0
# Inclination (deg from horizontal)                   0         0           0
# Azimuth (deg from North)                            0         0           0
# Shading Factor                                      0         0           0
# PV Area (m2)                                        0         0           0
# solar thermal description                           1         0           0
# solar thermal area (m2)                             1         0           0
# lighting description                                0         1           0
# lighting efficacy (lm/w)                            0         1           0
# lighting efficiency (W/m2.100lux)                   0         1           0
# lighting controls description                       0         1           0
# pump type description                               0         0           1
#
#                                         description  reference
# model_run                                         0          0
# description                                       1          0
# IesVersion                                        0          0
# BER_kgCO2/(m2.yr)                                 0          0
# TER_kgCO2/(m2.yr)                                 0          0
# london_plan_run                                   0          0
# report_run_name                                   0          0
# as_designed                                       0          0
# report_model_run                                  0          0
# counter                                           0          0
# tag                                               0          0
# tag1                                              0          0
# general ref                                       0          1
# drwg ref                                          0          1
# weather data ref                                  0          1
# carbon factor ref                                 0          1
# electricity emission factor kgCO2/kWh             0          0
# natural gas emission factor kgCO2/kWh             0          0
# fabric uvals/gvals                                0          0
# fabric description                                1          0
# Air Permeability (m3/h.m2 @50Pa)                  0          0
# vent description                                  1          0
# MVHR heat recovery sensible efficiency            0          0
# heating description                               1          0
# heating control description                       1          0
# heating SCoP                                      0          0
# heating SCoP ref                                  0          1
# vent heat recovery effectiveness                  0          0
# dhw description                                   1          0
# dhw SCoP                                          0          0
# dhw SCoP ref                                      0          1
# cooling description                               1          0
# SSEER                                             0          0
# SEER                                              0          0
# EER                                               0          0
# Delivery Efficiency                               0          0
# cooling ref                                       0          1
# cooling ref2                                      0          1
# pv description                                    1          0
# module nominal efficiency                         0          0
# Inclination (deg from horizontal)                 0          0
# Azimuth (deg from North)                          0          0
# Shading Factor                                    0          0
# PV Area (m2)                                      0          0
# solar thermal description                         1          0
# solar thermal area (m2)                           0          0
# lighting description                              1          0
# lighting efficacy (lm/w)                          0          0
# lighting efficiency (W/m2.100lux)                 0          0
# lighting controls description                     1          0
# pump type description                             1          0

# %%
df_colsfilt = m.df_colsfilt
li = list(df_colsfilt)
li.remove('user defined row filters')

# %%
li = list(m.df_colsfilt)
l=li[0]
colfilt = m.df_colsfilt.query('`{0}`==1'.format(l))[l].index.tolist()
colfilt
# Out:
# ['model_run',
#  'description',
#  'IesVersion',
#  'BER_kgCO2/(m2.yr)',
#  'TER_kgCO2/(m2.yr)',
#  'london_plan_run',
#  'report_run_name']

# %%
li_ui = []
for l in li:
    di = {}
    di['name'] = l
    nested = m.df_colsfilt.query('`{0}`==1'.format(l))[l].index.tolist()
    li_ = []
    for n in nested:
        di_ = {}
        di_['name'] = n
        di_['value'] = 'value'
        di_['label'] = n
        li_.append(di_)
    di['value'] = li_
    li_ui.append(di)

# %%
from ipyrun._ipyeditjson import EditListOfDicts
from IPython.display import JSON

# %%
JSON(li_ui)

# %%
mruns_ui = EditListOfDicts(li_ui)
mruns_ui
# Out:
# VBox(children=(HBox(children=(HBox(children=(HTML(value='<p>core</p>'), HBox(children=(ToggleButton(value=Fals…
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
